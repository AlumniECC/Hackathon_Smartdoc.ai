# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install llama-parse
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# https://cloud.llamaindex.ai/landing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os

os.environ["LLAMA_CLOUD_API_KEY"] = "your api  key"

# %%
from llama_parse import LlamaParse

documents = LlamaParse(
    result_type="markdown",
    parsing_instruction="""
    Il s'agit d'un Rapport sur la Solvabilité et la Situation Financière d'une compagnie d'assurance.
    """
    ).load_data("/content/drive/MyDrive/Hackathon_Smartdoc.ai/data/pdfs/sfcr_covea_2022.PDF")
# Out:
# Started parsing the file under job_id ab04873a-881c-4610-bd7e-a1e0663b1b73
# .

# %%
documents
# Out:
# [Document(id_='b02d2a34-7e88-40ea-b78f-65d45d53afb9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text="**COVÉA**\n**RAPPORT SUR LA SOLVABILITÉ**\n**ET LA SITUATION FINANCIÈRE**\n**2022**\n\n----\n\nSi vous avez besoin d'informations spécifiques ou d'une analyse détaillée concernant ce rapport, n'hésitez pas à me le faire savoir !", mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
# ...

# %%
with open('covea_parsed_output.md', 'w') as f:
    for doc in documents:
        f.write(doc.text + '\n')
